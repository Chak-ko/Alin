# %% [markdown]
# #Selamat Bertugas
# #Menggambar persamaan bidang
# # **Penyelesaian sistem linier**
# Penyelesaian sistem Persamaan linier dengan menggunakan eliminasi gausian
# Pertama kita selesaikan persamaan berikut:
#
# $$
# 8x_1x_2+x_3=19\\
# x_1+2x_2+x_3=9\\
# 2x_1+x_2-x_3=5\\
# $$
# Berikut penyelesaian dari persamaan diatas

# %%
import numpy as np
A=np.array([[8,9,1,19],[1,2,3,9],[2,1,1,5]])
print(A)
# Out:
# [[ 8  9  1 19]
#  [ 1  2  3  9]
#  [ 2  1  1  5]]

# %%
[[ 8  9  1 19]
 [ 1  2  3  9]
 [ 2  1  1  5]]
# Out:
#   File "<ipython-input-4-68ce1c4ce7e5>", line 1
#     [[ 8  9  1 19]
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ##Mendefinisikan fungsi operasi baris eliminasi GAUSS
#
# RowSwap() => Berfungsi unutuk menukar posisi persamaan
#
# 1.   RowSwap() => Berfungsi unutuk menukar posisi persamaan
#
# 2.   RowScale() => Berfungsi untuk mengkalikan persamaan dengan skala
#
# 3.   RowAdd() => Berfungsi untuk menambahkan persamaan yang salah satunya sudah dikalikan dengan skala

# %%
def RowSwap(A,k,l):
# =============================================================================
#     A is a NumPy array.  RowSwap will return duplicate array with rows
#     k and l swapped. (menukarkan persamaan)
# =============================================================================
    m = A.shape[0]  # m is number of rows in A (jumlah baris A)
    n = A.shape[1]  # n is number of columns in A (jumlah kolom A)

    B = np.copy(A).astype('float64')

    for j in range(n):
        temp = B[k][j]
        B[k][j] = B[l][j]
        B[l][j] = temp

    return B

def RowScale(A,k,scale):
# =============================================================================
#     A is a NumPy array.  RowScale will return duplicate array with the
#     entries of row k multiplied by scale. (mengalikan entry baris A dengan skala)
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        B[k][j] *= scale

    return B

def RowAdd(A,k,l,scale):
# =============================================================================
#     A is a numpy array.  RowAdd will return duplicate array with row
#     l modified.  The new values will be the old values of row l added to
#     the values of row k, multiplied by scale. (menambahkan nilai baris k dikalikan dengan skala)
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        B[l][j] += B[k][j]*scale

    return B

# %% [markdown]
# Tahapan penyelesaian dengan menggunakan Eliminasi Gauss

# %%
# Print Soal
print(A)
print("\n")

## Tukar baris 0 dengan 1
A1 = RowSwap(A,0,1)
print(A1,'\n')

## Tambahkan -8 kali baris 0 ke baris 1
A2 = RowAdd(A1,0,1,-8)
print(A2,'\n')

## Tambahkan -2 kali baris 0 ke baris 2
A3 = RowAdd(A2,0,2,-2)
print(A3,'\n')

## Kalikan baris 2 dengan -7
A4 = RowScale(A3,2,-7)
print(A4,'\n')

## Tambahkan 3 kali baris 1 ke baris 2
A5 = RowAdd(A4,1,2,3)
print(A5)

## Kalikan baris 2 dengan -1/34
A6 = RowScale(A5,2,-1/34)
print(A6)

## Kalikan baris 1 dengan -1/7
A7 = RowScale(A6,1,-1/7)
print(A7)

# %%
[[ 8  9  1 19]
 [ 1  2  3  9]
 [ 2  1  1  5]]


[[ 1.  2.  3.  9.]
 [ 8.  9.  1. 19.]
 [ 2.  1.  1.  5.]]

[[  1.   2.   3.   9.]
 [  0.  -7. -23. -53.]
 [  2.   1.   1.   5.]]

[[  1.   2.   3.   9.]
 [  0.  -7. -23. -53.]
 [  0.  -3.  -5. -13.]]

[[  1.   2.   3.   9.]
 [  0.  -7. -23. -53.]
 [ -0.  21.  35.  91.]]

[[  1.   2.   3.   9.]
 [  0.  -7. -23. -53.]
 [  0.   0. -34. -68.]]
[[  1.   2.   3.   9.]
 [  0.  -7. -23. -53.]
 [ -0.  -0.   1.   2.]]
[[ 1.          2.          3.          9.        ]
 [-0.          1.          3.28571429  7.57142857]
 [-0.         -0.          1.          2.        ]]

# %%
# Print Soal
print(A)
print("\n")

A1 = RowSwap(A,0,1)
print(A1,"\n")

A2 = RowAdd(A1,0,1,-8)
print(A2,"\n")

A3 = RowAdd(A2,0,2,-2)
print(A3,"\n")

A4= RowAdd(A3,2,1,-2)
print(A4,"\n")

A5 = RowScale(A4,1,-1)
print(A5,"\n")

A6 = RowAdd(A5,1,2,3)
print(A6,"\n")

A7 = RowScale(A6,2,1/34)
print(A7,"\n")

# %%
[[ 8  9  1 19]
 [ 1  2  3  9]
 [ 2  1  1  5]]


[[ 1.  2.  3.  9.]
 [ 8.  9.  1. 19.]
 [ 2.  1.  1.  5.]]

[[  1.   2.   3.   9.]
 [  0.  -7. -23. -53.]
 [  2.   1.   1.   5.]]

[[  1.   2.   3.   9.]
 [  0.  -7. -23. -53.]
 [  0.  -3.  -5. -13.]]

[[  1.   2.   3.   9.]
 [  0.  -1. -13. -27.]
 [  0.  -3.  -5. -13.]]

[[  1.   2.   3.   9.]
 [ -0.   1.  13.  27.]
 [  0.  -3.  -5. -13.]]

[[ 1.  2.  3.  9.]
 [-0.  1. 13. 27.]
 [ 0.  0. 34. 68.]]

[[ 1.  2.  3.  9.]
 [-0.  1. 13. 27.]
 [ 0.  0.  1.  2.]]
# Out:
#   File "<ipython-input-2-d52abfa407f0>", line 1
#     [[ 8  9  1 19]
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
